# %% [markdown]
# ## Read CSV

# %%
import pandas as pd

file_path = "Data\Document_Data_Download-2025-11-10.csv"

df = pd.read_csv(file_path)
# new_dataset = df.loc[0:20]
# new_dataset.to_csv("./Data/snippet_data_CC.csv")

# %%
# new_dataset.head()
len(df.index)
max_length_col2 = df['Family Summary'].astype(str).str.len().max()
print(f"The maximum length of an item in 'col2' is: {max_length_col2}")
# Out:
# The maximum length of an item in 'col2' is: 7395
